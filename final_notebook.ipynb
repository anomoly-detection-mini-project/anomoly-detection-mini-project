# %%
# imports

import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

import acquire as a

import wrangle as w

from env import get_connection
import os

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)

# %%
# acquire data
df  = a.acquire_data()

# %%
# peak into data
df.head()
# Out:
#      id     name  start_date    end_date  program_id        date      time  \
# 0   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:55:03
# 1   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:02
# 2   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:05
# 3   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:06
# 4  22.0    Teddy  2018-01-08  2018-05-17         2.0  2018-01-26  09:56:24
#
#                                   path  user_id            ip
# 0                                    /        1  97.105.19.61
# 1                              java-ii        1  97.105.19.61
# 2  java-ii/object-oriented-programming        1  97.105.19.61
# 3   slides/object_oriented_programming        1  97.105.19.61
# 4            javascript-i/conditionals        2  97.105.19.61

# %% [markdown]
# #### 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
# get lesson that appears to attract the most traffic consistently across cohorts (per program)
program_cohort_max_traffic_df = w.get_program_cohort_max_traffic(df)

# %%
# look into dataframe
program_cohort_max_traffic_df
# Out:
#     program_id        name                                      path  \
# 0          1.0      Arches                              javascript-i
# 1          1.0    Badlands               content/php_ii/command-line
# 2          1.0      Denali                  mkdocs/search_index.json
# 3          1.0      Denali                         prework/databases
# 4          1.0      Denali                 prework/versioning/github
# 5          1.0    Franklin                         javascript-ii/es6
# 6          1.0     Glacier                          content/html-css
# 7          1.0     Hampton                                  java-iii
# 8          1.0         Ike                                  html-css
# 9          1.0      Joshua                          content/html-css
# 10         1.0       Kings                                index.html
# 11         1.0      Lassen                                index.html
# 12         1.0     Olympic                              javascript-i
# 13         1.0      Quincy                     content/laravel/intro
# 14         2.0   Andromeda                                       toc
# 15         2.0        Apex                  search/search_index.json
# 16         2.0        Bash                  search/search_index.json
# 17         2.0  Betelgeuse                  search/search_index.json
# 18         2.0       Ceres                  search/search_index.json
# 19         2.0      Deimos                              javascript-i
# 20         2.0      Europa                                       toc
# 21         2.0     Fortuna                                       toc
# 22         2.0    Ganymede                  search/search_index.json
# 23         2.0    Hyperion                                       toc
# 24         2.0     Jupiter                                       toc
# 25         2.0     Kalypso                              javascript-i
# 26         2.0        Luna                              javascript-i
# 27         2.0     Mammoth                                    java-i
# 28         2.0       Marco                                       toc
# 29         2.0     Neptune                                       toc
# 30         2.0     Niagara                                    spring
# 31         2.0      Oberon       javascript-i/introduction/operators
# 32         2.0   Pinnacles                              javascript-i
# 33         2.0     Sequoia                                    spring
# 34         2.0       Teddy                                    spring
# 35         2.0     Ulysses                  mkdocs/search_index.json
# 36         2.0   Voyageurs                              javascript-i
# 37         2.0    Wrangell                                       toc
# 38         2.0      Xanadu                              javascript-i
# 39         2.0    Yosemite                                       toc
# 40         2.0        Zion                                       toc
# 41         3.0       Bayes  1-fundamentals/modern-data-scientist.jpg
# 42         3.0       Curie                   6-regression/1-overview
# 43         3.0      Darden                   classification/overview
# 44         3.0      Easley  classification/scale_features_or_not.svg
# 45         3.0    Florence    fundamentals/modern-data-scientist.jpg
# 46         4.0      Apollo                          content/html-css
#
#     proba_status
# 0       0.037352
# 1       0.078947
# 2       0.333333
# 3       0.333333
# 4       0.333333
# 5       0.149254
# 6       0.053114
# 7       0.042285
# 8       0.053097
# 9       0.064846
# 10      0.032308
# 11      0.096788
# 12      0.027634
# 13      0.035748
# 14      0.027278
# 15      0.049602
# 16      0.041460
# 17      0.027533
# 18      0.036742
# 19      0.029731
# 20      0.037577
# 21      0.038753
# 22      0.036413
# 23      0.037680
# 24      0.055341
# 25      0.028940
# 26      0.042989
# 27      0.031509
# 28      0.060667
# 29      0.067932
# 30      0.097598
# 31      0.120620
# 32      0.036392
# 33      0.057999
# 34      0.027049
# 35      0.027699
# 36      0.027534
# 37      0.041873
# 38      0.027958
# 39      0.036563
# 40      0.041749
# 41      0.027866
# 42      0.031805
# 43      0.039722
# 44      0.034765
# 45      0.079995
# 46      0.500000

# %% [markdown]
# #### 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %%
# get dataframe with graduates
grad_df = df[df.date > df.end_date]

# get topic that grads continue to reference
grad_progarm_max_traffic_df = w.get_program_max_traffic(df)

# peak into data
grad_progarm_max_traffic_df
# Out:
#    program_id                      path  proba_status
# 0         1.0                index.html      0.036385
# 1         2.0              javascript-i      0.026984
# 2         3.0  search/search_index.json      0.024180
# 3         4.0          content/html-css      0.500000

# %% [markdown]
# #### 7. Which lessons are least accessed?

# %%
# get dataframe with count of lessson visited
min_traffic = w.min_traffic(df)

# %%
# get dataframe with least count of lessson visited
min_traffic[min_traffic['count']==1].head(10)
# Out:
#                                      count
# where                                    1
# classification/explore-old               1
# decision-trees                           1
# aliases                                  1
# javascript-i/intruduction/operators      1
# javascript/loops                         1
# strudents                                1
# extra-exercises/j                        1
# java-iii/servelets                       1
# data-science-pipeline                    1

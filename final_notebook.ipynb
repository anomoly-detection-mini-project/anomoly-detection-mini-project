# %%
# imports

import pandas as pd
import numpy as np


import acquire as a
import explore as ex

from env import get_connection
import os

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)

# %%
# acquire data
df  = a.acquire_data()

# %%
# peak into data
df.head()
# Out:
#      id     name  start_date    end_date  program_id        date      time  \
# 0   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:55:03
# 1   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:02
# 2   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:05
# 3   8.0  Hampton  2015-09-22  2016-02-06         1.0  2018-01-26  09:56:06
# 4  22.0    Teddy  2018-01-08  2018-05-17         2.0  2018-01-26  09:56:24
#
#                                   path  user_id            ip
# 0                                    /      1.0  97.105.19.61
# 1                              java-ii      1.0  97.105.19.61
# 2  java-ii/object-oriented-programming      1.0  97.105.19.61
# 3   slides/object_oriented_programming      1.0  97.105.19.61
# 4            javascript-i/conditionals      2.0  97.105.19.61

# %% [markdown]
# <div class="alert alert-info">
#     <header>
#     <h2>Exploration Question 1:</h2>
#     </header>
#     <dl>
#         <dt>Which lesson appears to attract the most traffic consistently across cohorts (per program)?</dt>
#         <dd>- 'javascript-i' and </dd>
#         <dd>- Jupiter was the cohort that accessed the 'toc' lesson the most.</dd>
#         <dd>- 'javascript-i' was the second most accessed lesson. This lesson was also the most accessed by staff.</dd>
#     </dl>
# </div>

# %%
# get lesson that appears to attract the most traffic consistently across cohorts (per program)
program_cohort_max_traffic_df = ex.get_program_cohort_max_traffic(df)

# %%
# look into dataframe
program_cohort_max_traffic_df
# Out:
#     program_id        name                                               path  \
# 0          1.0      Arches                                       javascript-i
# 1          1.0    Badlands                        content/php_ii/command-line
# 2          1.0      Denali                           mkdocs/search_index.json
# 3          1.0      Denali                                  prework/databases
# 4          1.0      Denali                          prework/versioning/github
# 5          1.0    Franklin                                  javascript-ii/es6
# 6          1.0     Glacier                                   content/html-css
# 7          1.0     Hampton                                           java-iii
# 8          1.0         Ike                                           html-css
# 9          1.0      Joshua                                   content/html-css
# 10         1.0       Kings                                         index.html
# ...

# %% [markdown]
# <div class="alert alert-info">
#     <header>
#     <h2>Exploration Question 2:</h2>
#     </header>
#     <dl>
#         <dt>Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?</dt>
#         <dd>- 'toc' lesson was popular across multiple cohorts</dd>
#         <dd>- Jupiter was the cohort that accessed the 'toc' lesson the most.</dd>
#         <dd>- 'javascript-i' was the second most accessed lesson. This lesson was also the most accessed by staff.</dd>
#     </dl>
# </div>

# %%
#dataframe for q2
new_df=ex.Q_two(df)
new_df
# Out:
#                                                          path    ip
# name
# Andromeda                                                 toc   638
# Apex                                 search/search_index.json  1488
# Apollo                                       content/html-css     2
# Arches                                           javascript-i   294
# Badlands                          content/php_ii/command-line     6
# Bash                                 search/search_index.json   647
# Bayes                1-fundamentals/modern-data-scientist.jpg   650
# Betelgeuse                           search/search_index.json   749
# Ceres                                search/search_index.json  1380
# Curie                                 6-regression/1-overview   595
# Darden                                classification/overview  1103
# Deimos                                           javascript-i   858
# Denali                               mkdocs/search_index.json     1
# ...

# %%
#plots answer for q2
ex.plot_q2(new_df)

# %% [markdown]
# <div class="alert alert-info">
#     <header>
#     <h2>Exploration Question 5:</h2>
#     </header>
#     <dl>
#         <dt>At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?</dt>
#         <dd>- The web dev students were accessing the data science curriculum when the first data science cohort started at Codeup.</dd>
#         <dd>- In late 2019 it appears that access was cut off for both cohorts.</dd>
#         <dd>- The cross-access in 2020 could be instructor accounts/instructors transitioning from web dev to data science or web dev access could have been cut off later in 2020.</dd>
#     </dl>
# </div>

# %%
#Function for question 5 plot
ex.q5()

# %% [markdown]
# #### 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %%
# get dataframe with graduates
grad_df = df[df.date > df.end_date]

# get topic that grads continue to reference
grad_progarm_max_traffic_df = ex.get_program_max_traffic(df)

# peak into data
grad_progarm_max_traffic_df
# Out:
#    program_id                      path  proba_status
# 0         1.0                index.html      0.036460
# 1         2.0              javascript-i      0.026693
# 2         3.0  search/search_index.json      0.024335
# 3         4.0          content/html-css      0.500000

# %% [markdown]
# #### 7. Which lessons are least accessed?

# %%
# get dataframe with count of lessson visited
min_traffic = ex.min_traffic(df)

# %%
# get dataframe with least count of lessson visited
min_traffic[min_traffic['count']==1].head(10)
# Out:
#                                      count
# 8.0_Intro_Module                         1
# About_NLP                                1
# habn                                     1
# extra-features/file-upload               1
# extra-features/json-response             1
# content/mysql/clauses/order-by.html      1
# slides/css                               1
# slidesexceptions_and_errorhandlings      1
# javascri                                 1
# extra-challenges                         1
